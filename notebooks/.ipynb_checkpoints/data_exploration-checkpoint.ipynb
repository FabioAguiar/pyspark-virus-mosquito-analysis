# %%
#
import findspark
findspark.init()

#from warnings import filterwarnings
#filterwarnings(action='ignore', category=DeprecationWarning, message='`np.bool` is a deprecated alias')
#from collections import namedtuple
#import matplotlib

import pyspark.pandas as pspd
from pyspark.sql.functions import year, month, dayofmonth, current_date
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
#plt.style.use('ggplot')
#pd.options.plotting.backend = 'matplotlib'
# %matplotlib inline

# %%
#
psdf_dengue_2019 = pspd.read_csv('../data/raw/dengue_2019_recife.csv', sep=';')
psdf_dengue_2020 = pspd.read_csv('../data/raw/dengue_2020_recife.csv', sep=';')
psdf_dengue_2021 = pspd.read_csv('../data/raw/dengue_2021_recife.csv', sep=';')

psdf_chikun_2019 = pspd.read_csv('../data/raw/chikungunya_2019_recife.csv', sep=';')
psdf_chikun_2020 = pspd.read_csv('../data/raw/chikungunya_2020_recife.csv', sep=';')
psdf_chikun_2021 = pspd.read_csv('../data/raw/chikungunya_2021_recife.csv', sep=';')

psdf_zika_2019 = pspd.read_csv('../data/raw/zika_2019_recife.csv', sep=';')
psdf_zika_2020 = pspd.read_csv('../data/raw/zika_2020_recife.csv', sep=';')
psdf_zika_2021 = pspd.read_csv('../data/raw/zika_2021_recife.csv', sep=';')

#df = pd.read_csv('data/raw/vgsales.csv')
# Out:
# 23/08/14 17:14:14 WARN Utils: Your hostname, vmserver resolves to a loopback address: 127.0.1.1; using 192.168.0.103 instead (on interface enp0s3)
# 23/08/14 17:14:14 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/08/14 17:14:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: If `index_col` is not specified for `read_csv`, the default index is attached which can cause additional overhead.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %%
#
psdf_dengue_2019['virus']='DENGUE'
psdf_dengue_2019 = psdf_dengue_2019[['dt_notificacao', 'notificacao_ano', 'dt_nascimento', 'tp_sexo', 'no_bairro_residencia','virus']]
psdf_dengue_2019.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia   virus
# 0     2019-01-04             2019    2006-10-01       F          SANTO AMARO  DENGUE
# 1     2019-05-21             2019    2017-11-01       F           BOA VIAGEM  DENGUE
# 2     2019-01-09             2019    2012-03-01       M                IPSEP  DENGUE
# 3     2019-01-03             2019    2014-02-01       F               JORDAO  DENGUE
# 4     2019-01-02             2019    2018-05-01       M                IBURA  DENGUE

# %%
#
psdf_dengue_2020['virus']='DENGUE'
psdf_dengue_2020 = psdf_dengue_2020[['dt_notificacao', 'notificacao_ano', 'dt_nascimento', 'tp_sexo', 'no_bairro_residencia', 'virus']]
psdf_dengue_2020.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia   virus
# 0     2020-01-01             2020    1992-02-10       M           SAN MARTIN  DENGUE
# 1     2020-01-01             2020    1984-10-04       F                COHAB  DENGUE
# 2     2020-01-02             2020    1995-03-11       F          DOIS IRMAOS  DENGUE
# 3     2020-01-03             2020    1995-02-27       M              TORROES  DENGUE
# 4     2020-01-03             2020    1989-01-27       M             IPUTINGA  DENGUE

# %%
#
psdf_dengue_2021['virus']='DENGUE'
psdf_dengue_2021 = psdf_dengue_2021[['dt_notificacao', 'notificacao_ano', 'dt_nascimento', 'tp_sexo', 'no_bairro_residencia', 'virus']]
psdf_dengue_2021.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia   virus
# 0     2021-01-05             2021    1980-03-26       F                IBURA  DENGUE
# 1     2021-01-06             2021    1992-04-18       F           PASSARINHO  DENGUE
# 2     2021-01-06             2021    1993-11-29       F             IPUTINGA  DENGUE
# 3     2021-01-06             2021    2012-09-29       M                IBURA  DENGUE
# 4     2021-01-06             2021    1979-03-14       F               JORDAO  DENGUE

# %%
#
psdf_chikun_2019['virus']='CHIKUNGUNYA'
psdf_chikun_2019 = psdf_chikun_2019[['dt_notificacao', 'notificacao_ano', 'dt_nascimento', 'tp_sexo', 'no_bairro_residencia', 'virus']]
psdf_chikun_2019.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia        virus
# 0     2020-03-13             2020    1966-09-01       F                IBURA  CHIKUNGUNYA
# 1     2019-01-30             2019    1974-08-01       F             MADALENA  CHIKUNGUNYA
# 2     2019-05-13             2019    1995-09-01       F             IPUTINGA  CHIKUNGUNYA
# 3     2019-01-09             2019    1977-08-01       M             AFOGADOS  CHIKUNGUNYA
# 4     2019-01-03             2019    1999-10-01       M             AFOGADOS  CHIKUNGUNYA

# %%
#
psdf_chikun_2020['virus']='CHIKUNGUNYA'
psdf_chikun_2020 = psdf_chikun_2020[['dt_notificacao', 'notificacao_ano', 'dt_nascimento', 'tp_sexo', 'no_bairro_residencia', 'virus']]
psdf_chikun_2020.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia        virus
# 0     2020-01-03             2020    1994-10-08       M          IMBIRIBEIRA  CHIKUNGUNYA
# 1     2020-01-05             2020    1950-12-05       M           BOA VIAGEM  CHIKUNGUNYA
# 2     2020-01-06             2020    1962-02-20       F           PASSARINHO  CHIKUNGUNYA
# 3     2020-01-07             2020    1984-11-22       F        ALTO DO MANDU  CHIKUNGUNYA
# 4     2020-01-07             2020    1988-10-26       F           BOA VIAGEM  CHIKUNGUNYA

# %%
#
psdf_chikun_2021['virus']='CHIKUNGUNYA'
psdf_chikun_2021 = psdf_chikun_2021[['dt_notificacao', 'notificacao_ano', 'dt_nascimento', 'tp_sexo', 'no_bairro_residencia', 'virus']]
psdf_chikun_2021.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia        virus
# 0     2021-01-03             2021    2021-01-03       F        ALTO DO MANDU  CHIKUNGUNYA
# 1     2021-01-11             2021    1998-10-02       F          SANTO AMARO  CHIKUNGUNYA
# 2     2021-01-11             2021    1967-07-15       F                IBURA  CHIKUNGUNYA
# 3     2021-01-11             2021    1987-09-21       M                IBURA  CHIKUNGUNYA
# 4     2021-01-11             2021    1955-09-02       F        LINHA DO TIRO  CHIKUNGUNYA

# %%
#
psdf_zika_2019.rename(columns={"ano_notificacao": "notificacao_ano"}, inplace=True)
psdf_zika_2019['virus']='ZIKA'
psdf_zika_2019 = psdf_zika_2019[['dt_notificacao', 'notificacao_ano', 'dt_nascimento', 'tp_sexo', 'no_bairro_residencia', 'virus']]
psdf_zika_2019.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia virus
# 0     2019-01-25             2019           NaT       F              COELHOS  ZIKA
# 1     2019-01-07             2019           NaT       F      ENGENHO DO MEIO  ZIKA
# 2     2019-02-26             2019    2007-11-01       F             AFOGADOS  ZIKA
# 3     2019-02-13             2019    1990-06-01       M            GUABIRABA  ZIKA
# 4     2019-01-18             2019    1988-08-01       F            MANGUEIRA  ZIKA

# %%
#
psdf_zika_2020.rename(columns={"ano_notificacao": "notificacao_ano"}, inplace=True)
psdf_zika_2020['virus']='ZIKA'
psdf_zika_2020 = psdf_zika_2020[['dt_notificacao', 'notificacao_ano', 'dt_nascimento', 'tp_sexo', 'no_bairro_residencia', 'virus']]
psdf_zika_2020.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia virus
# 0     2020-01-08             2020    1990-07-23       M            BOA VISTA  ZIKA
# 1     2020-01-13             2020    1969-06-20       M           ESPINHEIRO  ZIKA
# 2     2020-01-14             2020    1980-06-19       F             CORDEIRO  ZIKA
# 3     2020-01-14             2020    2008-03-03       M        VASCO DA GAMA  ZIKA
# 4     2020-01-14             2020    2013-03-25       F            MACAXEIRA  ZIKA

# %%
#
psdf_zika_2021.rename(columns={"ano_notificacao": "notificacao_ano"}, inplace=True)
psdf_zika_2021['virus']='ZIKA'
psdf_zika_2021 = psdf_zika_2021[['dt_notificacao', 'notificacao_ano', 'dt_nascimento', 'tp_sexo', 'no_bairro_residencia', 'virus']]
psdf_zika_2021.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia virus
# 0     2021-01-11             2021    1998-10-02       F          SANTO AMARO  ZIKA
# 1     2021-01-27             2021    1976-11-25       M               VARZEA  ZIKA
# 2     2021-02-04             2021    1979-07-20       F               AREIAS  ZIKA
# 3     2021-02-10             2021    1959-07-06       F               GRACAS  ZIKA
# 4     2021-03-15             2021    1990-12-27       F               VARZEA  ZIKA

# %% [markdown]
# ## Concatenação
#
# Concatenação dos DataFrames.

# %%
psdf = pspd.concat([psdf_dengue_2019,psdf_chikun_2019,psdf_zika_2019, psdf_dengue_2020,psdf_chikun_2020,psdf_zika_2020, psdf_dengue_2021,psdf_chikun_2021,psdf_zika_2021])
psdf.head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia   virus
# 0     2019-01-04             2019    2006-10-01       F          SANTO AMARO  DENGUE
# 1     2019-05-21             2019    2017-11-01       F           BOA VIAGEM  DENGUE
# 2     2019-01-09             2019    2012-03-01       M                IPSEP  DENGUE
# 3     2019-01-03             2019    2014-02-01       F               JORDAO  DENGUE
# 4     2019-01-02             2019    2018-05-01       M                IBURA  DENGUE

# %%
psdf[psdf['virus'] == 'ZIKA'].head()
# Out:
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia virus
# 0     2019-01-25             2019           NaT       F              COELHOS  ZIKA
# 1     2019-01-07             2019           NaT       F      ENGENHO DO MEIO  ZIKA
# 2     2019-02-26             2019    2007-11-01       F             AFOGADOS  ZIKA
# 3     2019-02-13             2019    1990-06-01       M            GUABIRABA  ZIKA
# 4     2019-01-18             2019    1988-08-01       F            MANGUEIRA  ZIKA

# %% [markdown]
# ### Contagem de dados ausentes

# %%
#
psdf.isna().sum()
# Out:
# /opt/spark/python/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   fields = [
# /opt/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# dt_notificacao             0
# notificacao_ano            0
# dt_nascimento           1509
# tp_sexo                    1
# no_bairro_residencia     216
# virus                      0
# dtype: int64

# %%
psdf.isnull().sum()
# Out:
# /opt/spark/python/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   fields = [
# /opt/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# dt_notificacao             0
# notificacao_ano            0
# dt_nascimento           1509
# tp_sexo                    1
# no_bairro_residencia     216
# virus                      0
# dtype: int64

# %%
psdf = psdf.dropna()
psdf.isnull().sum()
# Out:
# /opt/spark/python/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   fields = [
# /opt/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# dt_notificacao          0
# notificacao_ano         0
# dt_nascimento           0
# tp_sexo                 0
# no_bairro_residencia    0
# virus                   0
# dtype: int64

# %% [markdown]
# ### Granularizando registros da data de notificação

# %%
psdf["notificacao_mes"] = psdf["dt_notificacao"].dt.month
psdf["notificacao_trimestre"] = psdf["dt_notificacao"].dt.quarter


# Dicionário de mapeamento de números para nomes de meses
meses_map = {
    1: "Janeiro",
    2: "Fevereiro",
    3: "Março",
    4: "Abril",
    5: "Maio",
    6: "Junho",
    7: "Julho",
    8: "Agosto",
    9: "Setembro",
    10: "Outubro",
    11: "Novembro",
    12: "Dezembro"
}

# Dicionário de mapeamento de números para os trimestres
trimestre_map = {
    1: "Q1",
    2: "Q2",
    3: "Q3",
    4: "Q4"
}

# Função de mapeamento para substituir os números pelos nomes dos meses
def aplicar_mes(numero):
    return meses_map[numero]

# Função de mapeamento para substituir os números pelos nomes do trimestre
def aplicar_trimestre(numero):
    return trimestre_map[numero]

psdf['notificacao_mes_nome'] = psdf["notificacao_mes"].apply(aplicar_mes)
psdf['notificacao_trimestre_nome'] = psdf["notificacao_trimestre"].apply(aplicar_trimestre)
# Out:
# /opt/spark/python/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   fields = [
# /opt/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   fields = [
# /opt/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
#Removendo as colunas númericas do mês e do trimestre
psdf = psdf[['dt_notificacao','notificacao_mes_nome','notificacao_trimestre_nome','notificacao_ano','dt_nascimento','tp_sexo','no_bairro_residencia','virus']]
psdf.rename(columns={"notificacao_mes_nome": "notificacao_mes"}, inplace=True)
psdf.rename(columns={"notificacao_trimestre_nome": "notificacao_trimestre"}, inplace=True)
psdf.head()
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao notificacao_mes notificacao_trimestre  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia   virus
# 0     2019-01-04         Janeiro                    Q1             2019    2006-10-01       F          SANTO AMARO  DENGUE
# 1     2019-05-21            Maio                    Q2             2019    2017-11-01       F           BOA VIAGEM  DENGUE
# 2     2019-01-09         Janeiro                    Q1             2019    2012-03-01       M                IPSEP  DENGUE
# 3     2019-01-03         Janeiro                    Q1             2019    2014-02-01       F               JORDAO  DENGUE
# 4     2019-01-02         Janeiro                    Q1             2019    2018-05-01       M                IBURA  DENGUE

# %% [markdown]
# # Análise 1: Distribuição de casos ao longo dos anos

# %%
casos_por_anos_df = pspd.DataFrame(psdf.groupby("notificacao_ano").size()).to_pandas()
casos_por_anos_df = casos_por_anos_df.reset_index()
casos_por_anos_df.rename(columns={0: "quantidade"}, inplace=True)
casos_por_anos_df
# Out:
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_pandas` loads all data into the driver's memory. It should only be used if the resulting pandas DataFrame is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)
#    notificacao_ano  quantidade
# 0             2019        8541
# 1             2020        6493
# 2             2021       23588

# %%
# Plota um gráfico de barras com a distribuição de casos por sexo
colors = ['darkred', 'pink', 'red']
plt.figure(figsize=(10, 6))
plt.bar(casos_por_anos_df['notificacao_ano'], casos_por_anos_df['quantidade'], color=colors )
plt.xlabel('Ano da notificação')
plt.ylabel('Quantidade')
plt.title(' Distribuição de casos ao longo dos anos.')
#plt.xticks(rotation=90)
plt.xticks(casos_por_anos_df['notificacao_ano'], rotation=45) 
plt.tight_layout()
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/fabyuu/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # Análise 2: Identificação dos meses com maior incidência de casos

# %%
incidencia_casos_meses = pspd.DataFrame(psdf.groupby("notificacao_mes").size().sort_values()).to_pandas()
incidencia_casos_meses = incidencia_casos_meses.reset_index()
incidencia_casos_meses.rename(columns={0: "quantidade"}, inplace=True)
incidencia_casos_meses
# Out:
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_pandas` loads all data into the driver's memory. It should only be used if the resulting pandas DataFrame is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#    notificacao_mes  quantidade
# 0         Dezembro         511
# 1          Janeiro         554
# 2        Fevereiro         709
# 3            Março         972
# 4         Novembro        1027
# 5          Outubro        1701
# 6            Abril        1723
# 7         Setembro        3125
# 8           Agosto        5250
# 9             Maio        5564
# 10           Junho        8535
# 11           Julho        8951

# %%
# Dicionário de mapeamento de números para nomes de meses
meses_map = {
    "Janeiro" : 1,
    "Fevereiro" : 2,
    "Março" : 3,
    "Abril" : 4,
    "Maio" : 5,
    "Junho" : 6,
    "Julho" : 7,
    "Agosto" : 8,
    "Setembro" : 9,
    "Outubro" : 10,
    "Novembro" : 11,
    "Dezembro" : 12
}

def criar_id_mes(mes):
    return meses_map[mes]

incidencia_casos_meses["id_mes"] = incidencia_casos_meses["notificacao_mes"].apply(criar_id_mes)
incidencia_casos_meses = incidencia_casos_meses.sort_values(by=['id_mes'], ascending=True)
incidencia_casos_meses
# Out:
#    notificacao_mes  quantidade  id_mes
# 1          Janeiro         554       1
# 2        Fevereiro         709       2
# 3            Março         972       3
# 6            Abril        1723       4
# 9             Maio        5564       5
# 10           Junho        8535       6
# 11           Julho        8951       7
# 8           Agosto        5250       8
# 7         Setembro        3125       9
# 5          Outubro        1701      10
# 4         Novembro        1027      11
# 0         Dezembro         511      12

# %%
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'purple', 'orange', 'pink', 'brown', 'gray']

plt.figure(figsize=(10, 6))
plt.bar(incidencia_casos_meses['notificacao_mes'], incidencia_casos_meses['quantidade'], color=colors )
plt.xlabel('Ano da notificação')
plt.ylabel('Quantidade')
plt.title(' Distribuição de casos ao longo dos anos.')
#plt.xticks(rotation=90)
plt.xticks(rotation=45) 
plt.tight_layout()
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/fabyuu/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # Análise 3: Comparação de casos entre os diferentes vírus ao longo dos anos

# %%
virus_ano_df = psdf.groupby(["virus", "notificacao_ano"]).size().unstack()
virus_ano_df = virus_ano_df.reset_index()
virus_ano_df = virus_ano_df.to_pandas()
#virus_ano_df.set_index('virus', inplace=True)  # Define a coluna 'virus' como índice
virus_ano_df

# Definindo os anos para o eixo x
anos = [2019, 2020, 2021]

# Plotando o gráfico de linhas
plt.figure(figsize=(10, 6))
for index, row in virus_ano_df.iterrows():
    plt.plot(anos, row[1:], marker='o', label=row['virus'])

# Configurando o gráfico
plt.title('Variação do Número de Casos por Vírus ao Longo dos Anos')
plt.xlabel('Ano')
plt.ylabel('Número de Casos')
plt.legend()
plt.grid(True)
plt.xticks(anos, rotation=45) 
plt.tight_layout()
plt.show()
# Out:
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_pandas` loads all data into the driver's memory. It should only be used if the resulting pandas DataFrame is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)

# %%
#psdf[psdf['no_bairro_residencia'] == 'CACOTE']
psdf.groupby("no_bairro_residencia").size().sort_index()
# Out:
# no_bairro_residencia
# 462                        1
# AFLITOS                   29
# AFOGADOS                 950
# AGUA FRIA               1686
# ALTO DA BONDADE            2
# ALTO DO MANDU            321
# ALTO DO PASCOAL            1
# ALTO JOSE BONIFACIO      751
# ALTO JOSE DO PINHO       301
# ALTO SANTA ISABEL          3
# ALTO SANTA TEREZINHA     189
# ALUIZIO PINTO              1
# APIPUCOS                  68
# AREIAS                   671
# ARRUDA                   682
# BAIRRO NOVO                1
# BARRO                    244
# BARROI                     1
# BEBERIBE                 376
# BOA                        1
# BOA VIAGEM              1076
# BOA VISTA                274
# BOMBA DO HEMETERIO       373
# BONGI                    205
# BRASILIA TEIMOSA         193
# BREJO                      2
# BREJO DA GUABIRABA       247
# BREJO DE BEBERIBE        254
# BREJO DE GUABIRABA         1
# CABANGA                   28
# CACOTE                    99
# CAJUEIRO                 372
# CAMPINA                    1
# CAMPINA DO BARRETO       825
# CAMPO                      1
# CAMPO GRANDE            1251
# CASA AMARELA             824
# CASA FORTE                86
# CAXANGA                  173
# CAÃOTE                     9
# CAþOTE                     5
# CENTRO                     3
# CHAO DE ESTRELAS           5
# CIDADE UNIVERSITARIA      25
# COELHOS                  241
# COHAB                   1479
# COQUEIRAL                103
# CORDEIRO                 761
# CORREGO DO JENIPAPO      202
# CURADO                   157
# ChÒo de Estrela            1
# DERBY                      5
# DOIS IRMAOS              118
# DOIS UNIDOS             1298
# ENCRUZILHADA             249
# ENG DO MEIO               15
# ENGE DO MEIO               1
# ENGENHO DO MEIO          398
# ESPINHEIRO                92
# ESTANCIA                 223
# ESTRADA DOS REMEDIOS       1
# FUNDAO                   372
# GRACAS                   121
# GRAþAS                     1
# GUABIRABA                222
# GUARARAPES                 1
# HIPODROMO                 60
# IBURA                   2498
# ILHA DO LEITE             17
# ILHA DO RETIRO            59
# ILHA JOANA BEZERRA       315
# IMBIRIBEIRA             1267
# IPS                        1
# IPSEP                    604
# IPUITINGA                  1
# IPUTINGA                1203
# JAQUEIRA                  12
# JARDIM SAO PAULO         646
# JARDIM S├O PAULO           1
# JD.JORDAO                  1
# JIGUIA                     1
# JIQUIA                   185
# JIQUI┴                     1
# JORDAO                   541
# JORDAO ALTO                1
# LINHA DO TIRO            771
# MACAXEIRA                402
# MADALENA                 316
# MANGABEIRA               136
# MANGUEIRA                223
# MONTEIRO                  89
# MORRO DA CONCEICAO       411
# MUSTARDINHA              271
# NI                         1
# NOVA DESCOBERTA         1085
# OURO PRETO                 1
# P                          1
# PACHECO                    1
# PAISSANDU                 11
# PARNAMIRIM                86
# PASSARINHO               605
# PASSSARINHO                1
# PEIXINHOS                126
# PINA                     614
# POCO                      58
# PONTO DE PARADA          123
# PORTO DA MADEIRA         239
# PRADO                    334
# RECIFE                    60
# RODA DE FOGO               2
# ROSARINHO                115
# RUA JERONIMO               1
# Recife                     1
# SAN MARTIN               659
# SANCHO                    61
# SANTA ROSA                 1
# SANTANA                   78
# SANTO AMARO              862
# SANTO ANTONIO             13
# SAO JOSE                 165
# SITIO DOS PINTOS         176
# SITIO NOVO                 1
# SOLEDADE                  18
# TAMARINEIRA              254
# TEJIPIO                  167
# TORRE                    269
# TORREAO                   24
# TORROES                  817
# TOTO                      46
# UR7 VARZEA                 3
# VARZEA                  1331
# VASCO DA GAMA           1235
# ZUMBI                    272
# dtype: int64

# %% [markdown]
# ## Correção de alguns registros do bairro

# %%
psdf[psdf['no_bairro_residencia'] == 'CAÃOTE']
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#       dt_notificacao notificacao_mes notificacao_trimestre  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia        virus
# 8828      2021-08-30          Agosto                    Q3             2021    1966-04-09       M               CAÃOTE       DENGUE
# 8880      2021-09-01        Setembro                    Q3             2021    1984-05-13       M               CAÃOTE       DENGUE
# 12576     2021-08-04          Agosto                    Q3             2021    1999-03-04       F               CAÃOTE  CHIKUNGUNYA
# 12710     2021-08-05          Agosto                    Q3             2021    2004-02-03       M               CAÃOTE  CHIKUNGUNYA
# 12976     2021-08-10          Agosto                    Q3             2021    1942-06-26       F               CAÃOTE  CHIKUNGUNYA
# 12977     2021-08-10          Agosto                    Q3             2021    1991-11-23       F               CAÃOTE  CHIKUNGUNYA
# 13072     2021-08-11          Agosto                    Q3             2021    2003-12-03       F               CAÃOTE  CHIKUNGUNYA
# 13618     2021-08-18          Agosto                    Q3             2021    2004-11-03       F               CAÃOTE  CHIKUNGUNYA
# 14277     2021-09-01        Setembro                    Q3             2021    2006-12-30       M               CAÃOTE  CHIKUNGUNYA

# %%
pd = psdf.to_pandas()
pd.head()

array_data = pd["no_bairro_residencia"].unique()

# Convertendo o array para um dicionário
dict_data = {value: value for value in array_data}
dict_data
# Out:
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_pandas` loads all data into the driver's memory. It should only be used if the resulting pandas DataFrame is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# {'SANTO AMARO': 'SANTO AMARO',
#  'BOA VIAGEM': 'BOA VIAGEM',
#  'IPSEP': 'IPSEP',
#  'JORDAO': 'JORDAO',
#  'IBURA': 'IBURA',
#  'PINA': 'PINA',
#  'CAMPO GRANDE': 'CAMPO GRANDE',
#  'SAO JOSE': 'SAO JOSE',
#  'CAMPINA DO BARRETO': 'CAMPINA DO BARRETO',
#  'ARRUDA': 'ARRUDA',
#  'BOMBA DO HEMETERIO': 'BOMBA DO HEMETERIO',
#  'ALTO JOSE BONIFACIO': 'ALTO JOSE BONIFACIO',
#  'VASCO DA GAMA': 'VASCO DA GAMA',
#  'NOVA DESCOBERTA': 'NOVA DESCOBERTA',
#  'PRADO': 'PRADO',
#  'CORDEIRO': 'CORDEIRO',
#  'IPUTINGA': 'IPUTINGA',
#  'TORROES': 'TORROES',
#  'VARZEA': 'VARZEA',
#  'AFOGADOS': 'AFOGADOS',
#  'BONGI': 'BONGI',
#  'SAN MARTIN': 'SAN MARTIN',
#  'JARDIM SAO PAULO': 'JARDIM SAO PAULO',
#  'COHAB': 'COHAB',
#  'COQUEIRAL': 'COQUEIRAL',
#  'ESTRADA DOS REMEDIOS': 'ESTRADA DOS REMEDIOS',
#  'JAQUEIRA': 'JAQUEIRA',
#  'ROSARINHO': 'ROSARINHO',
#  'IMBIRIBEIRA': 'IMBIRIBEIRA',
#  'AGUA FRIA': 'AGUA FRIA',
#  'FUNDAO': 'FUNDAO',
#  'LINHA DO TIRO': 'LINHA DO TIRO',
#  'GUABIRABA': 'GUABIRABA',
#  'CASA AMARELA': 'CASA AMARELA',
#  'ALTO DO MANDU': 'ALTO DO MANDU',
#  'MACAXEIRA': 'MACAXEIRA',
#  'ENGENHO DO MEIO': 'ENGENHO DO MEIO',
#  'MANGUEIRA': 'MANGUEIRA',
#  'AREIAS': 'AREIAS',
#  'ALTO SANTA TEREZINHA': 'ALTO SANTA TEREZINHA',
#  'DOIS UNIDOS': 'DOIS UNIDOS',
#  'PASSARINHO': 'PASSARINHO',
#  'ALTO JOSE DO PINHO': 'ALTO JOSE DO PINHO',
#  'MADALENA': 'MADALENA',
#  'TORRE': 'TORRE',
#  'ILHA DO RETIRO': 'ILHA DO RETIRO',
#  'BOA VISTA': 'BOA VISTA',
#  'TORREAO': 'TORREAO',
#  'CABANGA': 'CABANGA',
#  'COELHOS': 'COELHOS',
#  'TAMARINEIRA': 'TAMARINEIRA',
#  'SITIO DOS PINTOS': 'SITIO DOS PINTOS',
#  'ENCRUZILHADA': 'ENCRUZILHADA',
#  'BRASILIA TEIMOSA': 'BRASILIA TEIMOSA',
#  'CORREGO DO JENIPAPO': 'CORREGO DO JENIPAPO',
#  'CURADO': 'CURADO',
#  'GRACAS': 'GRACAS',
#  'CAJUEIRO': 'CAJUEIRO',
#  'PORTO DA MADEIRA': 'PORTO DA MADEIRA',
#  'MORRO DA CONCEICAO': 'MORRO DA CONCEICAO',
#  'DOIS IRMAOS': 'DOIS IRMAOS',
#  'MUSTARDINHA': 'MUSTARDINHA',
#  'ESTANCIA': 'ESTANCIA',
#  'CACOTE': 'CACOTE',
#  'BARRO': 'BARRO',
#  'SANCHO': 'SANCHO',
#  'BREJO DE BEBERIBE': 'BREJO DE BEBERIBE',
#  'CAXANGA': 'CAXANGA',
#  'ESPINHEIRO': 'ESPINHEIRO',
#  'ILHA JOANA BEZERRA': 'ILHA JOANA BEZERRA',
#  'MANGABEIRA': 'MANGABEIRA',
#  'BREJO DA GUABIRABA': 'BREJO DA GUABIRABA',
#  'TEJIPIO': 'TEJIPIO',
#  'AFLITOS': 'AFLITOS',
#  'CASA FORTE': 'CASA FORTE',
#  'ZUMBI': 'ZUMBI',
#  'BEBERIBE': 'BEBERIBE',
#  'SANTA ROSA': 'SANTA ROSA',
#  'SOLEDADE': 'SOLEDADE',
#  'TOTO': 'TOTO',
#  'HIPODROMO': 'HIPODROMO',
#  'MONTEIRO': 'MONTEIRO',
#  'PEIXINHOS': 'PEIXINHOS',
#  'JIQUIA': 'JIQUIA',
#  'PARNAMIRIM': 'PARNAMIRIM',
#  'APIPUCOS': 'APIPUCOS',
#  'PAISSANDU': 'PAISSANDU',
#  'POCO': 'POCO',
#  'CIDADE UNIVERSITARIA': 'CIDADE UNIVERSITARIA',
#  'PONTO DE PARADA': 'PONTO DE PARADA',
#  'RECIFE': 'RECIFE',
#  'DERBY': 'DERBY',
#  'BREJO DE GUABIRABA': 'BREJO DE GUABIRABA',
#  'ALTO SANTA ISABEL': 'ALTO SANTA ISABEL',
#  'ALUIZIO PINTO': 'ALUIZIO PINTO',
#  'BREJO': 'BREJO',
#  'CENTRO': 'CENTRO',
#  'OURO PRETO': 'OURO PRETO',
#  'RUA JERONIMO': 'RUA JERONIMO',
#  'SANTO ANTONIO': 'SANTO ANTONIO',
#  'ILHA DO LEITE': 'ILHA DO LEITE',
#  'SANTANA': 'SANTANA',
#  'PACHECO': 'PACHECO',
#  'GUARARAPES': 'GUARARAPES',
#  'JD.JORDAO': 'JD.JORDAO',
#  'CHAO DE ESTRELAS': 'CHAO DE ESTRELAS',
#  'ALTO DA BONDADE': 'ALTO DA BONDADE',
#  'SITIO NOVO': 'SITIO NOVO',
#  'CAMPO': 'CAMPO',
#  'BOA': 'BOA',
#  'P': 'P',
#  'JORDAO ALTO': 'JORDAO ALTO',
#  'UR7 VARZEA': 'UR7 VARZEA',
#  'RODA DE FOGO': 'RODA DE FOGO',
#  'JARDIM S├O PAULO': 'JARDIM S├O PAULO',
#  'ENG DO MEIO': 'ENG DO MEIO',
#  'CAMPINA': 'CAMPINA',
#  'ChÒo de Estrela': 'ChÒo de Estrela',
#  'CAÃOTE': 'CAÃOTE',
#  'CAþOTE': 'CAþOTE',
#  'IPS': 'IPS',
#  'BARROI': 'BARROI',
#  'GRAþAS': 'GRAþAS',
#  'ENGE DO MEIO': 'ENGE DO MEIO',
#  'Recife': 'Recife',
#  '462': '462',
#  'IPUITINGA': 'IPUITINGA',
#  'JIGUIA': 'JIGUIA',
#  'PASSSARINHO': 'PASSSARINHO',
#  'NI': 'NI',
#  'BAIRRO NOVO': 'BAIRRO NOVO',
#  'JIQUI┴': 'JIQUI┴',
#  'ALTO DO PASCOAL': 'ALTO DO PASCOAL'}

# %%
# Dicionário de mapeamento com a correcao dos nomes dos bairros
correcao_bairro_residencia = {"SANTO AMARO": "SANTO AMARO",
 "BOA VIAGEM": "BOA VIAGEM",
 "IPSEP": "IPSEP",
 "JORDAO": "JORDAO",
 "IBURA": "IBURA",
 "PINA": "PINA",
 "CAMPO GRANDE": "CAMPO GRANDE",
 "SAO JOSE": "SAO JOSE",
 "CAMPINA DO BARRETO": "CAMPINA DO BARRETO",
 "ARRUDA": "ARRUDA",
 "BOMBA DO HEMETERIO": "BOMBA DO HEMETERIO",
 "ALTO JOSE BONIFACIO": "ALTO JOSE BONIFACIO",
 "VASCO DA GAMA": "VASCO DA GAMA",
 "NOVA DESCOBERTA": "NOVA DESCOBERTA",
 "PRADO": "PRADO",
 "CORDEIRO": "CORDEIRO",
 "IPUTINGA": "IPUTINGA",
 "TORROES": "TORROES",
 "VARZEA": "VARZEA",
 "AFOGADOS": "AFOGADOS",
 "BONGI": "BONGI",
 "SAN MARTIN": "SAN MARTIN",
 "JARDIM SAO PAULO": "JARDIM SAO PAULO",
 "COHAB": "COHAB",
 "COQUEIRAL": "COQUEIRAL",
 "ESTRADA DOS REMEDIOS": "ESTRADA DOS REMEDIOS",
 "JAQUEIRA": "JAQUEIRA",
 "ROSARINHO": "ROSARINHO",
 "IMBIRIBEIRA": "IMBIRIBEIRA",
 "AGUA FRIA": "AGUA FRIA",
 "FUNDAO": "FUNDAO",
 "LINHA DO TIRO": "LINHA DO TIRO",
 "GUABIRABA": "GUABIRABA",
 "CASA AMARELA": "CASA AMARELA",
 "ALTO DO MANDU": "ALTO DO MANDU",
 "MACAXEIRA": "MACAXEIRA",
 "ENGENHO DO MEIO": "ENGENHO DO MEIO",
 "MANGUEIRA": "MANGUEIRA",
 "AREIAS": "AREIAS",
 "ALTO SANTA TEREZINHA": "ALTO SANTA TEREZINHA",
 "DOIS UNIDOS": "DOIS UNIDOS",
 "PASSARINHO": "PASSARINHO",
 "ALTO JOSE DO PINHO": "ALTO JOSE DO PINHO",
 "MADALENA": "MADALENA",
 "TORRE": "TORRE",
 "ILHA DO RETIRO": "ILHA DO RETIRO",
 "BOA VISTA": "BOA VISTA",
 "TORREAO": "TORREAO",
 "CABANGA": "CABANGA",
 "COELHOS": "COELHOS",
 "TAMARINEIRA": "TAMARINEIRA",
 "SITIO DOS PINTOS": "SITIO DOS PINTOS",
 "ENCRUZILHADA": "ENCRUZILHADA",
 "BRASILIA TEIMOSA": "BRASILIA TEIMOSA",
 "CORREGO DO JENIPAPO": "CORREGO DO JENIPAPO",
 "CURADO": "CURADO",
 "GRACAS": "GRACAS",
 "CAJUEIRO": "CAJUEIRO",
 "PORTO DA MADEIRA": "PORTO DA MADEIRA",
 "MORRO DA CONCEICAO": "MORRO DA CONCEICAO",
 "DOIS IRMAOS": "DOIS IRMAOS",
 "MUSTARDINHA": "MUSTARDINHA",
 "ESTANCIA": "ESTANCIA",
 "CACOTE": "CACOTE",
 "BARRO": "BARRO",
 "SANCHO": "SANCHO",
 "BREJO DE BEBERIBE": "BREJO DE BEBERIBE",
 "CAXANGA": "CAXANGA",
 "ESPINHEIRO": "ESPINHEIRO",
 "ILHA JOANA BEZERRA": "ILHA JOANA BEZERRA",
 "MANGABEIRA": "MANGABEIRA",
 "BREJO DA GUABIRABA": "BREJO DA GUABIRABA",
 "TEJIPIO": "TEJIPIO",
 "AFLITOS": "AFLITOS",
 "CASA FORTE": "CASA FORTE",
 "ZUMBI": "ZUMBI",
 "BEBERIBE": "BEBERIBE",
 "SANTA ROSA": "SANTA ROSA",
 "SOLEDADE": "SOLEDADE",
 "TOTO": "TOTO",
 "HIPODROMO": "HIPODROMO",
 "MONTEIRO": "MONTEIRO",
 "PEIXINHOS": "PEIXINHOS",
 "JIQUIA": "JIQUIA",
 "PARNAMIRIM": "PARNAMIRIM",
 "APIPUCOS": "APIPUCOS",
 "PAISSANDU": "PAISSANDU",
 "POCO": "POCO",
 "CIDADE UNIVERSITARIA": "CIDADE UNIVERSITARIA",
 "PONTO DE PARADA": "PONTO DE PARADA",
 "RECIFE": "RECIFE",
 "DERBY": "DERBY",
 "BREJO DE GUABIRABA": "BREJO DE GUABIRABA",
 "ALTO SANTA ISABEL": "ALTO SANTA ISABEL",
 "ALUIZIO PINTO": "ALUIZIO PINTO",
 "BREJO": "BREJO",
 "CENTRO": "CENTRO",
 "OURO PRETO": "OURO PRETO",
 "RUA JERONIMO": "RUA JERONIMO",
 "SANTO ANTONIO": "SANTO ANTONIO",
 "ILHA DO LEITE": "ILHA DO LEITE",
 "SANTANA": "SANTANA",
 "PACHECO": "PACHECO",
 "GUARARAPES": "GUARARAPES",
 "JD.JORDAO": "JD.JORDAO",
 "CHAO DE ESTRELAS": "CHAO DE ESTRELAS",
 "ALTO DA BONDADE": "ALTO DA BONDADE",
 "SITIO NOVO": "SITIO NOVO",
 "CAMPO": "CAMPO GRANDE",
 "BOA": "BOA VISTA",
 "P": "PACHECO",
 "JORDAO ALTO": "JORDAO ALTO",
 "UR7 VARZEA": "UR7 VARZEA",
 "RODA DE FOGO": "RODA DE FOGO",
 "JARDIM S├O PAULO": "JARDIM SAO PAULO",
 "ENG DO MEIO": "ENGENHO DO MEIO",
 "CAMPINA": "CAMPINA DO BARRETO",
 "ChÒo de Estrela": "CHAO DE ESTRELAS",
 "CAÃOTE": "CACOTE",
 "CAþOTE": "CACOTE",
 "IPS": "IPSEP",
 "BARROI": "BARRO",
 "GRAþAS": "GRACAS",
 "ENGE DO MEIO": "ENGENHO DO MEIO",
 "Recife": "RECIFE",
 "462": "462",
 "IPUITINGA": "IPUTINGA",
 "JIGUIA": "JIGUIA",
 "PASSSARINHO": "PASSSARINHO",
 "NI": "SANTO ANTONIO",
 "BAIRRO NOVO": "BAIRRO NOVO",
 "JIQUI┴": "JIQUIA",
 "ALTO DO PASCOAL": "ALTO DO PASCOAL"
}

# Função de mapeamento para substituir os nomes dos bairros
def aplicar_correcao(bairro):
    return correcao_bairro_residencia[bairro]


pd["no_bairro_residencia_novo"] = pd["no_bairro_residencia"].map(aplicar_correcao)

#Removendo e renomeando coluna
pd = pd[['dt_notificacao','notificacao_mes','notificacao_trimestre','notificacao_ano','dt_nascimento','tp_sexo','no_bairro_residencia_novo','virus']]
pd.rename(columns={"no_bairro_residencia_novo": "no_bairro_residencia"}, inplace=True)

psdf = pspd.DataFrame(pd)
psdf.head()
# Out:
# /opt/spark/python/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   fields = [
# /opt/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# 23/08/14 17:15:11 WARN TaskSetManager: Stage 132 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao notificacao_mes notificacao_trimestre  notificacao_ano dt_nascimento tp_sexo no_bairro_residencia   virus
# 0     2019-01-04         Janeiro                    Q1             2019    2006-10-01       F          SANTO AMARO  DENGUE
# 1     2019-05-21            Maio                    Q2             2019    2017-11-01       F           BOA VIAGEM  DENGUE
# 2     2019-01-09         Janeiro                    Q1             2019    2012-03-01       M                IPSEP  DENGUE
# 3     2019-01-03         Janeiro                    Q1             2019    2014-02-01       F               JORDAO  DENGUE
# 4     2019-01-02         Janeiro                    Q1             2019    2018-05-01       M                IBURA  DENGUE

# %%
#Correção dos nomes dos bairros concluída
psdf[psdf['no_bairro_residencia'] == 'CAÃOTE']
# Out:
# 23/08/14 17:15:11 WARN TaskSetManager: Stage 133 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
# 23/08/14 17:15:11 WARN TaskSetManager: Stage 134 contains a task of very large size (1104 KiB). The maximum recommended task size is 1000 KiB.
# Empty DataFrame
# Columns: [dt_notificacao, notificacao_mes, notificacao_trimestre, notificacao_ano, dt_nascimento, tp_sexo, no_bairro_residencia, virus]
# Index: []

# %% [markdown]
# ## Criar coluna com a idade

# %%
psdf['ano_nasc'] = year('dt_nascimento')
psdf['idade'] = psdf['notificacao_ano'] - psdf['ano_nasc']

#Removendo a coluna ano_nasc
psdf = psdf[['dt_notificacao','notificacao_mes','notificacao_trimestre','notificacao_ano','dt_nascimento', 'idade', 'tp_sexo','no_bairro_residencia','virus']]
psdf.head()
# Out:
# 23/08/14 17:15:12 WARN TaskSetManager: Stage 135 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /opt/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
#   dt_notificacao notificacao_mes notificacao_trimestre  notificacao_ano dt_nascimento  idade tp_sexo no_bairro_residencia   virus
# 0     2019-01-04         Janeiro                    Q1             2019    2006-10-01     13       F          SANTO AMARO  DENGUE
# 1     2019-05-21            Maio                    Q2             2019    2017-11-01      2       F           BOA VIAGEM  DENGUE
# 2     2019-01-09         Janeiro                    Q1             2019    2012-03-01      7       M                IPSEP  DENGUE
# 3     2019-01-03         Janeiro                    Q1             2019    2014-02-01      5       F               JORDAO  DENGUE
# 4     2019-01-02         Janeiro                    Q1             2019    2018-05-01      1       M                IBURA  DENGUE

# %% [markdown]
# ## Analise 4: Distribuição de casos por faixa etária

# %%
# Calcula a distribuição de casos por faixa etária
group_dengue = psdf[psdf['virus'] == "DENGUE"]
group_chikun = psdf[psdf['virus'] == "CHIKUNGUNYA"]
group_zika = psdf[psdf['virus'] == "ZIKA"]

group_dengue = group_dengue.sort_values(by=['idade'], ascending=False).groupby('idade').count()
group_dengue = group_dengue['dt_notificacao']
group_dengue.rename(columns={"dt_notificacao": "quantidade (dengue)"}, inplace=True)
group_dengue = group_dengue.reset_index()
#group_dengue.sort_values()

group_chikun = group_chikun.sort_values(by=['idade'], ascending=False).groupby('idade').count()
group_chikun = group_chikun['dt_notificacao']
group_chikun.rename(columns={"dt_notificacao": "quantidade (chikun)"}, inplace=True)
group_chikun = group_chikun.reset_index()
#group_chikun.sort_values()

group_zika = group_zika.sort_values(by=['idade'], ascending=False).groupby('idade').count()
group_zika = group_zika['dt_notificacao']
group_zika = pspd.DataFrame(group_zika)
group_zika.rename(columns={"dt_notificacao": "quantidade (zika)"}, inplace=True)
group_zika = group_zika.reset_index()
group_zika.head()
# Out:
# 23/08/14 17:15:12 WARN TaskSetManager: Stage 136 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
#    idade  quantidade (zika)
# 0     31                 26
# 1     85                  1
# 2     53                 10
# 3     34                 16
# 4     28                 14

# %%
# Plotando o gráfico de distribuição de casos por idade
plt.figure(figsize=(10, 6))
plt.hist(group_zika['idade'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribuição de Casos por Idade (Zika)')
plt.xlabel('Idade')
plt.ylabel('Número de Casos')
plt.grid(True)
plt.show()
# Out:
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)
# 23/08/14 17:15:13 WARN TaskSetManager: Stage 139 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.

# %%
# Plotando o gráfico de distribuição de casos por idade
plt.figure(figsize=(10, 6))
plt.hist(group_dengue['idade'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribuição de Casos por Idade (Dengue)')
plt.xlabel('Idade')
plt.ylabel('Número de Casos')
plt.grid(True)
plt.show()
# Out:
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)
# 23/08/14 17:15:13 WARN TaskSetManager: Stage 142 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.

# %%
# Plotando o gráfico de distribuição de casos por idade
plt.figure(figsize=(10, 6))
plt.hist(group_chikun['idade'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribuição de Casos por Idade (Chikungunya)')
plt.xlabel('Idade')
plt.ylabel('Número de Casos')
plt.grid(True)
plt.show()
# Out:
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_numpy` loads all data into the driver's memory. It should only be used if the resulting NumPy ndarray is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)
# 23/08/14 17:15:14 WARN TaskSetManager: Stage 145 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.

# %% [markdown]
# ## Analise 5: Comparar a distribuição de casos por sexo (tp_sexo) e vírus.

# %%
group_sexo_virus = psdf.groupby(['virus', 'tp_sexo']).count()
group_sexo_virus = group_sexo_virus['dt_notificacao']
group_sexo_virus = pspd.DataFrame(group_sexo_virus)
group_sexo_virus.rename(columns={"dt_notificacao": "quantidade"}, inplace=True)
group_sexo_virus.sort_index()
# Out:
# 23/08/14 17:15:15 WARN TaskSetManager: Stage 148 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
#                      quantidade
# virus       tp_sexo
# CHIKUNGUNYA F             10747
#             I                43
#             M              7664
# DENGUE      F             10371
#             I                35
#             M              8842
# ZIKA        F               629
#             M               291

# %%
group_sexo_virus = group_sexo_virus.reset_index()
group_sexo_virus
# Out:
# 23/08/14 17:15:15 WARN TaskSetManager: Stage 151 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
#          virus tp_sexo  quantidade
# 0       DENGUE       I          35
# 1       DENGUE       M        8842
# 2         ZIKA       M         291
# 3         ZIKA       F         629
# 4  CHIKUNGUNYA       I          43
# 5  CHIKUNGUNYA       M        7664
# 6  CHIKUNGUNYA       F       10747
# 7       DENGUE       F       10371

# %%
correcao = {
    "I": "NÃO INFORMADO",
    "M": "MASCULINO",
    "F": "FEMININO"
}

def correcao_sexo(caracter):
    return correcao[caracter]


group_sexo_virus['sexo'] = group_sexo_virus["tp_sexo"].apply(correcao_sexo)
group_sexo_virus.info
# Out:
# 23/08/14 17:15:16 WARN TaskSetManager: Stage 154 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
# /opt/spark/python/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   fields = [
# /opt/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# 23/08/14 17:15:16 WARN TaskSetManager: Stage 157 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# <bound method DataFrame.info of          virus tp_sexo  quantidade           sexo
# 0       DENGUE       I          35  NÃO INFORMADO
# 1       DENGUE       M        8842      MASCULINO
# 2         ZIKA       M         291      MASCULINO
# 3         ZIKA       F         629       FEMININO
# 4  CHIKUNGUNYA       I          43  NÃO INFORMADO
# 5  CHIKUNGUNYA       M        7664      MASCULINO
# 6  CHIKUNGUNYA       F       10747       FEMININO
# 7       DENGUE       F       10371       FEMININO>

# %%
# Converte o resultado para um pandas DataFrame para visualização
group_sexo_virus_df = group_sexo_virus.to_pandas()



# Plota um gráfico de barras com a distribuição de casos por sexo
colors = ['lightcoral', 'lightgreen','skyblue',]
plt.figure(figsize=(10, 6))
plt.bar(group_sexo_virus_df['sexo'], group_sexo_virus_df['quantidade'].where(group_sexo_virus_df['virus'] == 'CHIKUNGUNYA'), color=colors )
plt.xlabel('Sexo')
plt.ylabel('Quantidade')
plt.title('Comparar a distribuição de casos Chikungunya.')
#plt.xticks(rotation=90)
plt.xticks(rotation=45) 
plt.tight_layout()
plt
# Out:
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_pandas` loads all data into the driver's memory. It should only be used if the resulting pandas DataFrame is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)
# 23/08/14 17:15:17 WARN TaskSetManager: Stage 160 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# <module 'matplotlib.pyplot' from '/home/fabyuu/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
# Plota um gráfico de barras com a distribuição de casos por sexo
colors = ['lightcoral', 'lightgreen','skyblue']
plt.figure(figsize=(10, 6))
plt.bar(group_sexo_virus_df['sexo'], group_sexo_virus_df['quantidade'].where(group_sexo_virus_df['virus'] != 'DENGUE'), color=colors)
plt.xlabel('Sexo')
plt.ylabel('Quantidade')
plt.title('Comparar a distribuição de casos Dengue.')
#plt.xticks(rotation=90)
plt.xticks(rotation=45) 
plt.tight_layout()
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/fabyuu/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
# Plota um gráfico de barras com a distribuição de casos por sexo
colors = ['skyblue', 'lightcoral']
plt.figure(figsize=(10, 6))
plt.bar(group_sexo_virus_df['sexo'], group_sexo_virus_df['quantidade'].where(group_sexo_virus_df['virus'] == 'ZIKA'), color=colors )
plt.xlabel('Sexo')
plt.ylabel('Quantidade')
plt.title('Comparar a distribuição de casos Zika.')
#plt.xticks(rotation=90)
plt.xticks(rotation=45) 
plt.tight_layout()
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/fabyuu/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Analise 6: Agrupar os dados pelo nome do bairro e verificar a distribuição de casos em cada bairro

# %%
#Transformando a coluna de indices em uma coluna
df_incidencia_bairro = pspd.DataFrame(psdf.sort_values(by=['no_bairro_residencia'], ascending=False).groupby(['no_bairro_residencia'])['dt_notificacao'].count())
df_incidencia_bairro = df_incidencia_bairro.reset_index()
df_incidencia_bairro.rename(columns={"dt_notificacao": "quantidade"}, inplace=True)
df_incidencia_bairro = df_incidencia_bairro.to_pandas()
df_incidencia_bairro = df_incidencia_bairro.sort_values(by=['quantidade'], ascending=False)
df_incidencia_bairro.head()
# Out:
# /opt/spark/python/pyspark/pandas/utils.py:975: PandasAPIOnSparkAdviceWarning: `to_pandas` loads all data into the driver's memory. It should only be used if the resulting pandas DataFrame is expected to be small.
#   warnings.warn(message, PandasAPIOnSparkAdviceWarning)
# 23/08/14 17:15:18 WARN TaskSetManager: Stage 163 contains a task of very large size (1084 KiB). The maximum recommended task size is 1000 KiB.
#    no_bairro_residencia  quantidade
# 51                IBURA        2498
# 98            AGUA FRIA        1686
# 14                COHAB        1479
# 47               VARZEA        1331
# 96          DOIS UNIDOS        1298

# %%
# Plotar o gráfico de barras
plt.figure(figsize=(10, 8))
ax = df_incidencia_bairro.head(20).plot(kind='barh', x='no_bairro_residencia', y='quantidade', color='skyblue')
plt.title('Distribuição dos 20 bairros com mais incidência')
ax.bar_label(ax.containers[0])
plt.xlabel('Bairro')
plt.ylabel('Total de Casos')
plt.tight_layout()
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/fabyuu/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>
